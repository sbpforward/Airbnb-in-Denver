# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Calendar CSV

# %%
df_cal = pd.read_csv('../data/calendar.csv')

# %%
df_cal.head(50)
# Out:
#     listing_id        date available    price adjusted_price  minimum_nights  \
# 0       172196  2019-06-29         f  $350.00        $350.00               3
# 1          360  2019-06-29         f  $127.00        $127.00               2
# 2          360  2019-06-30         f  $127.00        $127.00               1
# 3          360  2019-07-01         f  $127.00        $127.00               1
# 4          360  2019-07-02         f  $127.00        $127.00               1
# 5          360  2019-07-03         f  $127.00        $127.00               1
# 6          360  2019-07-04         f  $127.00        $127.00               1
# 7          360  2019-07-05         f  $127.00        $127.00               1
# 8          360  2019-07-06         f  $127.00        $127.00               2
# 9          360  2019-07-07         f  $127.00        $127.00               1
# 10         360  2019-07-08         f  $131.00        $131.00               1
# ...

# %%
df_cal.tail(20)
# Out:
#          listing_id        date available    price adjusted_price  \
# 1646495    35606018  2020-06-08         f  $174.00        $174.00
# 1646496    35606018  2020-06-09         f  $164.00        $164.00
# 1646497    35606018  2020-06-10         f  $186.00        $186.00
# 1646498    35606018  2020-06-11         f  $244.00        $244.00
# 1646499    35606018  2020-06-12         f  $300.00        $300.00
# 1646500    35606018  2020-06-13         f  $310.00        $310.00
# 1646501    35606018  2020-06-14         f  $224.00        $224.00
# 1646502    35606018  2020-06-15         f  $176.00        $176.00
# 1646503    35606018  2020-06-16         f  $164.00        $164.00
# 1646504    35606018  2020-06-17         f  $186.00        $186.00
# 1646505    35606018  2020-06-18         f  $246.00        $246.00
# 1646506    35606018  2020-06-19         f  $302.00        $302.00
# 1646507    35606018  2020-06-20         f  $314.00        $314.00
# ...

# %%
df_cal.columns
# Out:
# Index(['listing_id', 'date', 'available', 'price', 'adjusted_price',
#        'minimum_nights', 'maximum_nights'],
#       dtype='object')

# %%
# Checking to make sure the dates are consectuive

df_cal['date'].unique()
# Out:
# array(['2019-06-29', '2019-06-30', '2019-07-01', '2019-07-02',
#        '2019-07-03', '2019-07-04', '2019-07-05', '2019-07-06',
#        '2019-07-07', '2019-07-08', '2019-07-09', '2019-07-10',
#        '2019-07-11', '2019-07-12', '2019-07-13', '2019-07-14',
#        '2019-07-15', '2019-07-16', '2019-07-17', '2019-07-18',
#        '2019-07-19', '2019-07-20', '2019-07-21', '2019-07-22',
#        '2019-07-23', '2019-07-24', '2019-07-25', '2019-07-26',
#        '2019-07-27', '2019-07-28', '2019-07-29', '2019-07-30',
#        '2019-07-31', '2019-08-01', '2019-08-02', '2019-08-03',
#        '2019-08-04', '2019-08-05', '2019-08-06', '2019-08-07',
#        '2019-08-08', '2019-08-09', '2019-08-10', '2019-08-11',
#        '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#        '2019-08-16', '2019-08-17', '2019-08-18', '2019-08-19',
#        '2019-08-20', '2019-08-21', '2019-08-22', '2019-08-23',
#        '2019-08-24', '2019-08-25', '2019-08-26', '2019-08-27',
# ...

# %%
# Found one of our listings! 

df_cal.loc[df_cal['listing_id'] == 23453925]
# Out:
#         listing_id        date available   price adjusted_price  \
# 899700    23453925  2019-06-29         f  $46.00         $46.00
# 899701    23453925  2019-06-30         f  $44.00         $44.00
# 899702    23453925  2019-07-01         f  $44.00         $44.00
# 899703    23453925  2019-07-02         f  $45.00         $45.00
# 899704    23453925  2019-07-03         f  $44.00         $44.00
# 899705    23453925  2019-07-04         f  $46.00         $46.00
# 899706    23453925  2019-07-05         f  $46.00         $46.00
# 899707    23453925  2019-07-06         f  $46.00         $46.00
# 899708    23453925  2019-07-07         f  $46.00         $46.00
# 899709    23453925  2019-07-08         f  $44.00         $44.00
# 899710    23453925  2019-07-09         f  $46.00         $46.00
# 899711    23453925  2019-07-10         f  $46.00         $46.00
# 899712    23453925  2019-07-11         f  $46.00         $46.00
# 899713    23453925  2019-07-12         f  $46.00         $46.00
# ...

# %%
# And our other listing! 
df_cal.loc[df_cal['listing_id'] == 25232441]
# Out:
#         listing_id        date available   price adjusted_price  \
# 941237    25232441  2019-06-29         f  $47.00         $47.00
# 941238    25232441  2019-06-30         f  $47.00         $47.00
# 941239    25232441  2019-07-01         f  $47.00         $47.00
# 941240    25232441  2019-07-02         f  $48.00         $48.00
# 941241    25232441  2019-07-03         f  $47.00         $47.00
# 941242    25232441  2019-07-04         f  $47.00         $47.00
# 941243    25232441  2019-07-05         f  $49.00         $49.00
# 941244    25232441  2019-07-06         f  $49.00         $49.00
# 941245    25232441  2019-07-07         f  $48.00         $48.00
# 941246    25232441  2019-07-08         f  $48.00         $48.00
# 941247    25232441  2019-07-09         f  $47.00         $47.00
# 941248    25232441  2019-07-10         f  $48.00         $48.00
# 941249    25232441  2019-07-11         f  $49.00         $49.00
# 941250    25232441  2019-07-12         f  $49.00         $49.00
# ...

# %%
# Seeing which columns need to be converted 

df_cal.dtypes
# Out:
# listing_id         int64
# date              object
# available         object
# price             object
# adjusted_price    object
# minimum_nights     int64
# maximum_nights     int64
# dtype: object

# %%
df_cal.loc[df_cal['date'] == '2020-06-01']
# Out:
#          listing_id        date available    price adjusted_price  \
# 352             360  2020-06-01         t  $153.00        $153.00
# 898          172196  2020-06-01         t  $434.00        $434.00
# 1069            364  2020-06-01         t  $179.00        $179.00
# 1558            590  2020-06-01         f   $67.00         $67.00
# 2030            592  2020-06-01         f   $42.00         $42.00
# 2163         177942  2020-06-01         f  $213.00        $213.00
# 2587            686  2020-06-01         t   $75.00         $75.00
# 3239           1940  2020-06-01         f  $104.00        $104.00
# 3580        1678845  2020-06-01         t  $120.00        $120.00
# 3835         184529  2020-06-01         t   $35.00         $35.00
# 4110           2086  2020-06-01         t   $81.00         $81.00
# 4501        1724186  2020-06-01         f   $83.00         $83.00
# 5019          21745  2020-06-01         t   $70.00         $70.00
# ...

# %%
df_cal.shape
# Out:
# (1646515, 7)

# %% [markdown]
# # Listing CSV

# %%
df_lst = pd.read_csv('../data/listings.csv')

# %%
df_lst.head()
# Out:
#     id                       listing_url       scrape_id last_scraped  \
# 0  360  https://www.airbnb.com/rooms/360  20190629051303   2019-06-29
# 1  364  https://www.airbnb.com/rooms/364  20190629051303   2019-06-29
# 2  590  https://www.airbnb.com/rooms/590  20190629051303   2019-06-29
# 3  592  https://www.airbnb.com/rooms/592  20190629051303   2019-06-29
# 4  686  https://www.airbnb.com/rooms/686  20190629051303   2019-06-29
#
#                                           name  \
# 0  LoHi Secret garden at the Chickadee Cottage
# 1          Lodo / RiNo LOFT  via airport train
# 2            Comfortable  - and a great value!
# 3                                      private
# 4            Alexandra's Uptown Queen Bed Room
#
#                                              summary  \
# 0  Come enjoy our oasis is the city and stay at o...
# 1  Modern 1,000 square foot loft in the heart of ...
# 2  Large guest room in my home, where I also live...
# ...

# %%
df_lst.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        ...
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object', length=106)

# %%
df_lst.dtypes
# Out:
# id                                                int64
# listing_url                                      object
# scrape_id                                         int64
# last_scraped                                     object
# name                                             object
# summary                                          object
# space                                            object
# description                                      object
# experiences_offered                              object
# neighborhood_overview                            object
# notes                                            object
# transit                                          object
# access                                           object
# interaction                                      object
# house_rules                                      object
# thumbnail_url                                   float64
# medium_url                                      float64
# ...

# %%
col = df_lst.columns.tolist()
col
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
# ...

# %%
df_lst['neighbourhood_cleansed'].unique().tolist()
# Out:
# ['Highland',
#  'Five Points',
#  'North Park Hill',
#  'North Capitol Hill',
#  'Baker',
#  'Hale',
#  'West Highland',
#  'Capitol Hill',
#  'Overland',
#  'City Park',
#  'Washington Park',
#  'Union Station',
#  'South Park Hill',
#  'University Park',
#  'Washington Park West',
#  'Clayton',
#  'City Park West',
#  'Berkeley',
#  'Stapleton',
#  'Jefferson Park',
#  'Lowry Field',
#  'Platt Park',
#  'Sunnyside',
#  'Congress Park',
#  'Goldsmith',
#  'Sloan Lake',
#  'Barnum',
#  'Speer',
#  'CBD',
#  'Lincoln Park',
#  'Cole',
#  'Cheesman Park',
#  'University',
#  'Washington Virginia Vale',
#  'West Colfax',
#  'Cory - Merrill',
#  'Whittier',
#  'Montclair',
#  'Hilltop',
#  'Skyland',
#  'Country Club',
#  'Villa Park',
#  'Athmar Park',
#  'Fort Logan',
#  'Windsor',
#  'Gateway - Green Valley Ranch',
#  'Indian Creek',
#  'Rosedale',
#  'Bear Valley',
#  'Barnum West',
#  'Cherry Creek',
#  'Harvey Park',
#  'Ruby Hill',
#  'Hampden South',
#  'Civic Center',
# ...

# %%
# Checking out how long notes might be and if it's something I want to include when cleaning
# the data

df_lst['notes'].iloc[150]
# Out:
# "DENVER SHORT TERM LICENSE # (Phone number hidden by Airbnb) BFN (Phone number hidden by Airbnb) It's perfectly charming, beautiful and bright..... with a super location to boot.  Easy access to downtown Denver, the State Capital, 16th Street Mall, Convention Center, Pepsi Center, Sports Authority Field, Coors Field and Cherry Creek Mall. Our home is  located in Capital Hill, Denver,  voted one of the 10 most beautiful neighborhoods in the US.  This neighborhood is electric and colorful and one of the most vibrant and convenient locations in all of Denver, with a walk score of 96, which is a walkers paradise.   Markets.....Natural Grocers is 5 blocks away, King Scoopers is 8 blocks away as is Trader Joe's........ Safeway is approximately 9 blocks.  Located on historic Pearl St. the home is modern and fun. Attractions are also a short walk.... (5 blocks) to the State Capital building and 16th Street Mall (6 blocks) puts you in the middle of downtown. ….less than 3 miles from any of De
# ...

# %%
df_lst['property_type'].unique()
# Out:
# array(['Guesthouse', 'Loft', 'House', 'Apartment', 'Bed and breakfast',
#        'Guest suite', 'Cottage', 'Townhouse', 'Condominium', 'Bungalow',
#        'Serviced apartment', 'Tiny house', 'Castle', 'Other', 'Hostel',
#        'Villa', 'Camper/RV', 'Tent', 'Campsite'], dtype=object)

# %%
df_lst['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)

# %%
# Can see who has their license number on their listing and who does not

df_lst['license'].head()
# Out:
# 0    2017-BFN-0002177
# 1                 NaN
# 2    2018-BFN-O0O5791
# 3    2018-BFN-O0O5791
# 4    2016-BFN-0008368
# Name: license, dtype: object

# %%
df_lst.shape
# Out:
# (4511, 106)

# %% [markdown]
# # Review CSV

# %%
df_rev = pd.read_csv('../data/reviews.csv')

# %%
df_rev.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0         360  307152490  2018-08-13     46723582     Madeleine
# 1         360  311601388  2018-08-21     68751664       Janelle
# 2         360  312497032  2018-08-23     57773484          Ziad
# 3         360  313089933  2018-08-24     11982181        Andrea
# 4         360  314492150  2018-08-26     14620568          Iris
#
#                                             comments
# 0  This space was perfect! Great location, hosts,...
# 1  Hidden Gem in Denver. Magical Secret garden ce...
# 2  Amazing stay at one of the best kept AirBnB se...
# 3  The cottage has a great setting with a garden ...
# 4  Super cute place, very peaceful (loved the gar...

# %%
df_rev.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %%
df_rev.dtypes
# Out:
# listing_id        int64
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object

# %%
df_rev.shape
# Out:
# (221847, 6)
